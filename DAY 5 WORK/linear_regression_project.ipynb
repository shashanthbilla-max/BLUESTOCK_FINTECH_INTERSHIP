# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
df=pd.read_csv("D:\handson\machine_leraning\CAR-DETAILS-FROM-CAR-DEKHO (1).csv")
df
# Out:
#                                      name  year  selling_price  km_driven  \
# 0                           Maruti 800 AC  2007          60000      70000
# 1                Maruti Wagon R LXI Minor  2007         135000      50000
# 2                    Hyundai Verna 1.6 SX  2012         600000     100000
# 3                  Datsun RediGO T Option  2017         250000      46000
# 4                   Honda Amaze VX i-DTEC  2014         450000     141000
# ...                                   ...   ...            ...        ...
# 4335  Hyundai i20 Magna 1.4 CRDi (Diesel)  2014         409999      80000
# 4336           Hyundai i20 Magna 1.4 CRDi  2014         409999      80000
# 4337                  Maruti 800 AC BSIII  2009         110000      83000
# 4338     Hyundai Creta 1.6 CRDi SX Option  2016         865000      90000
# 4339                     Renault KWID RXT  2016         225000      40000
#
#         fuel seller_type transmission         owner
# ...

# %%
df.head()
# Out:
#                        name  year  selling_price  km_driven    fuel  \
# 0             Maruti 800 AC  2007          60000      70000  Petrol
# 1  Maruti Wagon R LXI Minor  2007         135000      50000  Petrol
# 2      Hyundai Verna 1.6 SX  2012         600000     100000  Diesel
# 3    Datsun RediGO T Option  2017         250000      46000  Petrol
# 4     Honda Amaze VX i-DTEC  2014         450000     141000  Diesel
#
#   seller_type transmission         owner
# 0  Individual       Manual   First Owner
# 1  Individual       Manual   First Owner
# 2  Individual       Manual   First Owner
# 3  Individual       Manual   First Owner
# 4  Individual       Manual  Second Owner

# %%
df.describe()
# Out:
#               year  selling_price      km_driven
# count  4340.000000   4.340000e+03    4340.000000
# mean   2013.090783   5.041273e+05   66215.777419
# std       4.215344   5.785487e+05   46644.102194
# min    1992.000000   2.000000e+04       1.000000
# 25%    2011.000000   2.087498e+05   35000.000000
# 50%    2014.000000   3.500000e+05   60000.000000
# 75%    2016.000000   6.000000e+05   90000.000000
# max    2020.000000   8.900000e+06  806599.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4340 entries, 0 to 4339
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           4340 non-null   object
#  1   year           4340 non-null   int64
#  2   selling_price  4340 non-null   int64
#  3   km_driven      4340 non-null   int64
#  4   fuel           4340 non-null   object
#  5   seller_type    4340 non-null   object
#  6   transmission   4340 non-null   object
#  7   owner          4340 non-null   object
# dtypes: int64(3), object(5)
# memory usage: 271.4+ KB

# %%
df.isnull().sum()
# Out:
# name             0
# year             0
# selling_price    0
# km_driven        0
# fuel             0
# seller_type      0
# transmission     0
# owner            0
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# 0

# %%
df.duplicated().sum()
# Out:
# 763

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3577 entries, 0 to 4339
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           3577 non-null   object
#  1   year           3577 non-null   int64
#  2   selling_price  3577 non-null   int64
#  3   km_driven      3577 non-null   int64
#  4   fuel           3577 non-null   object
#  5   seller_type    3577 non-null   object
#  6   transmission   3577 non-null   object
#  7   owner          3577 non-null   object
# dtypes: int64(3), object(5)
# memory usage: 251.5+ KB

# %%
for i in df.columns:
    if df[i].dtype!="object":
        sns.boxplot(df[i])
        plt.xlabel(i)
        plt.show()

# %%
df.columns
# Out:
# Index(['name', 'year', 'selling_price', 'km_driven', 'fuel', 'seller_type',
#        'transmission', 'owner'],
#       dtype='object')

# %%
col=['year','km_driven','selling_price']

# %%
for i in col:
    q1=df[i].quantile(0.25)
    q3=df[i].quantile(0.75)
    IQR=q3-q1
    LB=q1-0.5*IQR
    UP=q3+0.5*IQR
    df=df[(df[i]>=LB) & (df[i]<=UP)]

# %%
for i in df.columns:
    if df[i].dtype!="object":
        sns.boxplot(df[i])
        plt.xlabel(i)
        plt.show()

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
for i in df.columns:
    if df[i].dtype=="object":
        df[i]=le.fit_transform(df[i])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2398 entries, 0 to 4339
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           2398 non-null   int32
#  1   year           2398 non-null   int64
#  2   selling_price  2398 non-null   int64
#  3   km_driven      2398 non-null   int64
#  4   fuel           2398 non-null   int32
#  5   seller_type    2398 non-null   int32
#  6   transmission   2398 non-null   int32
#  7   owner          2398 non-null   int32
# dtypes: int32(5), int64(3)
# memory usage: 121.8 KB

# %%
df
# Out:
#       name  year  selling_price  km_driven  fuel  seller_type  transmission  \
# 0      519  2007          60000      70000     3            1             1
# 1      738  2007         135000      50000     3            1             1
# 2      332  2012         600000     100000     1            1             1
# 3       62  2017         250000      46000     3            1             1
# 6      364  2016         550000      25000     3            1             1
# ...    ...   ...            ...        ...   ...          ...           ...
# 4333   638  2012         225000      90000     1            1             1
# 4335   420  2014         409999      80000     1            1             1
# 4336   419  2014         409999      80000     1            1             1
# 4337   520  2009         110000      83000     3            1             1
# 4339   806  2016         225000      40000     3            1             1
#
#       owner
# 0         0
# 1         0
# 2         0
# ...

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
df.columns
# Out:
# Index(['name', 'year', 'selling_price', 'km_driven', 'fuel', 'seller_type',
#        'transmission', 'owner'],
#       dtype='object')

# %%
col_list = []
for i in df.columns:
    if i != 'selling_price':
        col_list.append(i)
X = df[col_list]

vif_data = pd.DataFrame()
vif_data['column_name'] = X.columns
vif_data['VIF_score'] = [variance_inflation_factor(X.values, i) for i in range(len(X.columns))]
vif_data
# Out:
#     column_name  VIF_score
# 0          name   4.548726
# 1          year  38.927080
# 2     km_driven   7.345122
# 3          fuel   6.042963
# 4   seller_type   4.738241
# 5  transmission  20.887800
# 6         owner   1.723807

# %%
x=df.drop(['transmission'], axis=1)
x
# Out:
#       name  year  selling_price  km_driven  fuel  seller_type  owner
# 0      519  2007          60000      70000     3            1      0
# 1      738  2007         135000      50000     3            1      0
# 2      332  2012         600000     100000     1            1      0
# 3       62  2017         250000      46000     3            1      0
# 6      364  2016         550000      25000     3            1      0
# ...    ...   ...            ...        ...   ...          ...    ...
# 4333   638  2012         225000      90000     1            1      2
# 4335   420  2014         409999      80000     1            1      2
# 4336   419  2014         409999      80000     1            1      2
# 4337   520  2009         110000      83000     3            1      2
# 4339   806  2016         225000      40000     3            1      0
#
# [2398 rows x 7 columns]

# %%
x.columns
# Out:
# Index(['name', 'year', 'selling_price', 'km_driven', 'fuel', 'seller_type',
#        'owner'],
#       dtype='object')

# %%
col_list = []
for i in x.columns:
    if i != 'selling_price':
        col_list.append(i)
X = df[col_list]

vif_data = pd.DataFrame()
vif_data['column_name'] = X.columns
vif_data['VIF_score'] = [variance_inflation_factor(X.values, i) for i in range(len(X.columns))]
vif_data
# Out:
#    column_name  VIF_score
# 0         name   4.547339
# 1         year  20.492454
# 2    km_driven   7.304538
# 3         fuel   6.024877
# 4  seller_type   4.714061
# 5        owner   1.723794

# %%
x = df[['year',
        'km_driven',
        'fuel',
        'seller_type',
        'owner']]

y = df['selling_price']

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
x_train
# Out:
#       year  km_driven  fuel  seller_type  owner
# 2721  2012      44000     3            1      0
# 3324  2016      41000     1            1      0
# 2478  2016      28643     3            0      0
# 840   2014      35000     3            1      0
# 1655  2012      50000     1            1      0
# ...    ...        ...   ...          ...    ...
# 2898  2016      73000     1            0      0
# 1855  2013      65000     1            1      0
# 1928  2010      50000     3            1      2
# 2209  2009      38500     3            1      2
# 1436  2015      30000     3            1      0
#
# [1918 rows x 5 columns]

# %%
x_test
# Out:
#       year  km_driven  fuel  seller_type  owner
# 755   2018      40890     1            0      0
# 326   2017      88635     1            0      0
# 2681  2010      80000     1            1      2
# 2207  2017      50000     3            1      0
# 2136  2011      60000     1            1      4
# ...    ...        ...   ...          ...    ...
# 1484  2010      90000     1            1      4
# 206   2014      55000     3            0      0
# 453   2018      24000     3            1      0
# 2513  2013      50000     1            1      0
# 1738  2008      41723     3            1      2
#
# [480 rows x 5 columns]

# %%
y_train
# Out:
# 2721    330000
# 3324    520000
# 2478    396000
# 840     500000
# 1655    200000
#          ...
# 2898    690000
# 1855    185000
# 1928     80000
# 2209    110000
# 1436    600000
# Name: selling_price, Length: 1918, dtype: int64

# %%
y_test
# Out:
# 755     790000
# 326     700000
# 2681     99000
# 2207    280000
# 2136    195000
#          ...
# 1484    320000
# 206     265000
# 453     420000
# 2513    420000
# 1738    120000
# Name: selling_price, Length: 480, dtype: int64

# %%
from sklearn.linear_model import LinearRegression

le = LinearRegression()
le.fit(x_train, y_train)
y_pred = le.predict(x_test)

# %%
y_pred
# Out:
# array([624553.50700741, 581463.11078006, 283937.52299765, 451487.48036686,
#        301799.12598403, 448497.03425655, 282139.26035033, 555136.33640862,
#        357023.1895515 , 372415.92786597, 519541.36544122, 520687.31478155,
#        339610.52801113, 379596.49413921, 381394.75678653, 452983.95185362,
#        269817.09872815, 421228.57890272, 238358.5232114 , 257613.42227785,
#        418195.80264997, 378401.81381302, 555136.33640862, 355828.50922529,
#        499610.48168059, 554352.03708832, 561122.22235565, 199869.02857009,
#        379596.49413921, 438970.84459037, 549054.52802518, 397009.15567957,
#        496858.60026295, 325868.9020585 , 342456.32069919, 492670.62368435,
#        286628.6748106 , 468154.40302704, 488445.58859746, 343129.73286822,
#        561122.22235565, 491922.38794096, 334751.67612433, 372415.92786597,
#        355828.50922529, 464113.93001279, 409669.68487777, 592782.12181161,
# ...

# %%
from sklearn.metrics import r2_score
r2_score(y_test, y_pred)
# Out:
# 0.4666212490546586

# %%
from sklearn.metrics import mean_absolute_error
mean_absolute_error(y_test, y_pred)
# Out:
# 112984.09337655203

# %%
df1=pd.DataFrame()
df1["actual values"]=y_test
df1["predicted values"]=y_pred
df1
# Out:
#       actual values  predicted values
# 755          790000     624553.507007
# 326          700000     581463.110780
# 2681          99000     283937.522998
# 2207         280000     451487.480367
# 2136         195000     301799.125984
# ...             ...               ...
# 1484         320000     261364.218410
# 206          265000     369025.271296
# 453          420000     491323.799346
# 2513         420000     417340.249900
# 1738         120000     108139.838691
#
# [480 rows x 2 columns]

# %%
fig=plt.figure(figsize=(10,6))
sns.regplot(x="actual values", y="predicted values", data=df1)
plt.xlabel("actual values")
plt.ylabel("predicted values")
plt.title("linear regression")
plt.show()
