# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# %%
df=pd.read_csv("D:\\BULESTOCK_INTERSHIP\\DAY 2 WORK\\bajaj-2003-2020.csv")
df
# Out:
#           Symbol Series         Date  Prev Close  Open Price  High Price  \
# 0     BAJAUTOFIN     EQ  01-Jan-2003       48.10       49.50       49.50
# 1     BAJAUTOFIN     EQ  02-Jan-2003       49.00       49.00       49.25
# 2     BAJAUTOFIN     EQ  03-Jan-2003       49.00       48.00       49.25
# 3     BAJAUTOFIN     EQ  06-Jan-2003       49.15       46.00       48.75
# 4     BAJAUTOFIN     EQ  07-Jan-2003       48.55       47.00       49.25
# ...          ...    ...          ...         ...         ...         ...
# 4383  BAJFINANCE     EQ  20-Jul-2020     3301.30     3344.95     3453.95
# 4384  BAJFINANCE     EQ  21-Jul-2020     3441.50     3500.00     3519.50
# 4385  BAJFINANCE     EQ  22-Jul-2020     3292.45     3320.00     3340.00
# 4386  BAJFINANCE     EQ  23-Jul-2020     3253.00     3253.00     3320.00
# 4387  BAJFINANCE     EQ  24-Jul-2020     3297.80     3245.00     3290.00
#
#       Low Price  Last Price  Close Price  Average Price  \
# ...

# %%
df.head()
# Out:
#        Symbol Series         Date  Prev Close  Open Price  High Price  \
# 0  BAJAUTOFIN     EQ  01-Jan-2003       48.10        49.5       49.50
# 1  BAJAUTOFIN     EQ  02-Jan-2003       49.00        49.0       49.25
# 2  BAJAUTOFIN     EQ  03-Jan-2003       49.00        48.0       49.25
# 3  BAJAUTOFIN     EQ  06-Jan-2003       49.15        46.0       48.75
# 4  BAJAUTOFIN     EQ  07-Jan-2003       48.55        47.0       49.25
#
#    Low Price  Last Price  Close Price  Average Price  Total Traded Quantity  \
# 0       48.5        49.0        49.00          49.14                   3595
# 1       49.0        49.0        49.00          49.04                   1975
# 2       48.0        49.1        49.15          48.83                    761
# 3       46.0        48.5        48.55          48.27                    809
# 4       47.0        49.0        49.00          48.86                   1138
#
#     Turnover No. of Trades
# 0  176665.00             -
# 1   96852.50             -
# ...

# %%
df.tail()
# Out:
#           Symbol Series         Date  Prev Close  Open Price  High Price  \
# 4383  BAJFINANCE     EQ  20-Jul-2020     3301.30     3344.95     3453.95
# 4384  BAJFINANCE     EQ  21-Jul-2020     3441.50     3500.00     3519.50
# 4385  BAJFINANCE     EQ  22-Jul-2020     3292.45     3320.00     3340.00
# 4386  BAJFINANCE     EQ  23-Jul-2020     3253.00     3253.00     3320.00
# 4387  BAJFINANCE     EQ  24-Jul-2020     3297.80     3245.00     3290.00
#
#       Low Price  Last Price  Close Price  Average Price  \
# 4383    3316.50     3436.00      3441.50        3389.56
# 4384    3218.65     3304.00      3292.45        3385.18
# 4385    3193.60     3250.00      3253.00        3265.62
# 4386    3216.05     3296.05      3297.80        3288.19
# 4387    3220.00     3250.00      3251.85        3251.26
#
#       Total Traded Quantity      Turnover No. of Trades
# 4383               10556334  3.578134e+10        358852
# 4384               25960105  8.787972e+10        979111
# ...

# %%
df.shape
# Out:
# (4388, 13)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4388 entries, 0 to 4387
# Data columns (total 13 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Symbol                 4388 non-null   object
#  1   Series                 4388 non-null   object
#  2   Date                   4388 non-null   object
#  3   Prev Close             4388 non-null   float64
#  4   Open Price             4388 non-null   float64
#  5   High Price             4388 non-null   float64
#  6   Low Price              4388 non-null   float64
#  7   Last Price             4388 non-null   float64
#  8   Close Price            4388 non-null   float64
#  9   Average Price          4388 non-null   float64
#  10  Total Traded Quantity  4388 non-null   int64
#  11  Turnover               4388 non-null   float64
#  12  No. of Trades          4388 non-null   object
# dtypes: float64(8), int64(1), object(4)
# memory usage: 445.8+ KB

# %%
df.describe()
# Out:
#          Prev Close    Open Price    High Price     Low Price    Last Price  \
# count   4388.000000   4388.000000   4388.000000   4388.000000   4388.000000
# mean    1490.448758   1491.950761   1516.892238   1465.826335   1491.892835
# std     1835.012417   1834.770995   1861.882447   1805.930079   1835.310492
# min        1.000000      1.000000      1.000000      1.000000      1.000000
# 25%      306.712500    306.112500    314.000000    300.000000    306.750000
# 50%      704.950000    705.000000    716.500000    693.000000    705.975000
# 75%     1965.625000   1971.250000   2022.350000   1927.775000   1965.750000
# max    11393.300000  11300.000000  11770.000000  11294.000000  11386.700000
#
#         Close Price  Average Price  Total Traded Quantity      Turnover
# count   4388.000000    4388.000000           4.388000e+03  4.388000e+03
# mean    1491.754879    1492.061192           5.473569e+05  1.370234e+09
# ...

# %%
df.isnull().sum()
# Out:
# Symbol                   0
# Series                   0
# Date                     0
# Prev Close               0
# Open Price               0
# High Price               0
# Low Price                0
# Last Price               0
# Close Price              0
# Average Price            0
# Total Traded Quantity    0
# Turnover                 0
# No. of Trades            0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
for i in df.columns:
    if df[i].dtype == 'object':
        print(i)
        print(df[i].value_counts())
        print("--------------------------------")
# Out:
# Symbol
# Symbol
# BAJFINANCE    2434
# BAJAUTOFIN    1954
# Name: count, dtype: int64
# --------------------------------
# Series
# Series
# EQ    4365
# W1      12
# N1      10
# BL       1
# Name: count, dtype: int64
# --------------------------------
# Date
# Date
# 05-Jan-2010    3
# 04-Jan-2010    3
# 10-Nov-2009    2
# 29-Dec-2009    2
# 23-Oct-2007    2
#               ..
# 20-Oct-2008    1
# 21-Oct-2008    1
# 22-Oct-2008    1
# 23-Oct-2008    1
# 24-Jul-2020    1
# Name: count, Length: 4365, dtype: int64
# --------------------------------
# No. of Trades
# No. of Trades
# -              2122
#         255       4
# 664               3
# 311               3
# 682               3
#                ...
# 1321              1
# 4751              1
# 3721              1
# 3701              1
# 257319            1
# Name: count, Length: 2166, dtype: int64
# --------------------------------

# %%
df["Date"] = pd.to_datetime(df["Date"])

# %%
df["Year"] = df["Date"].dt.year
df["Month"] = df["Date"].dt.month

# %%
df
# Out:
#           Symbol Series       Date  Prev Close  Open Price  High Price  \
# 0     BAJAUTOFIN     EQ 2003-01-01       48.10       49.50       49.50
# 1     BAJAUTOFIN     EQ 2003-01-02       49.00       49.00       49.25
# 2     BAJAUTOFIN     EQ 2003-01-03       49.00       48.00       49.25
# 3     BAJAUTOFIN     EQ 2003-01-06       49.15       46.00       48.75
# 4     BAJAUTOFIN     EQ 2003-01-07       48.55       47.00       49.25
# ...          ...    ...        ...         ...         ...         ...
# 4383  BAJFINANCE     EQ 2020-07-20     3301.30     3344.95     3453.95
# 4384  BAJFINANCE     EQ 2020-07-21     3441.50     3500.00     3519.50
# 4385  BAJFINANCE     EQ 2020-07-22     3292.45     3320.00     3340.00
# 4386  BAJFINANCE     EQ 2020-07-23     3253.00     3253.00     3320.00
# 4387  BAJFINANCE     EQ 2020-07-24     3297.80     3245.00     3290.00
#
#       Low Price  Last Price  Close Price  Average Price  \
# 0         48.50       49.00        49.00          49.14
# ...

# %%
corr = df.corr(numeric_only=True)

print(corr)
# Out:
#                        Prev Close  Open Price  High Price  Low Price  \
# Prev Close               1.000000    0.996161    0.995952   0.995903
# Open Price               0.996161    1.000000    0.999744   0.999760
# High Price               0.995952    0.999744    1.000000   0.999612
# Low Price                0.995903    0.999760    0.999612   1.000000
# Last Price               0.995768    0.999562    0.999811   0.999748
# Close Price              0.995783    0.999573    0.999818   0.999769
# Average Price            0.995960    0.999766    0.999893   0.999872
# Total Traded Quantity    0.161647    0.161567    0.165514   0.157537
# Turnover                 0.216282    0.216969    0.220959   0.212851
# Year                     0.663051    0.664013    0.664103   0.663289
# Month                   -0.009447   -0.010601   -0.011243  -0.009575
#
#                        Last Price  Close Price  Average Price  \
# Prev Close               0.995768     0.995783       0.995960
# ...

# %%
plt.figure(figsize=(12,8))
sns.heatmap(corr, annot=True, cmap="coolwarm")
plt.show()

# %%
num_cols = df.select_dtypes(include=np.number).columns

for col in num_cols:
    plt.figure(figsize=(5,3))
    plt.hist(df[col], bins=20)
    plt.title(col)
    plt.show()

# %%
df.columns
# Out:
# Index(['Symbol', 'Series', 'Date', 'Prev Close', 'Open Price', 'High Price',
#        'Low Price', 'Last Price', 'Close Price', 'Average Price',
#        'Total Traded Quantity', 'Turnover', 'No. of Trades', 'Year', 'Month'],
#       dtype='object')

# %%
for col in num_cols:
    plt.figure(figsize=(5,3))
    sns.boxplot(df[col])
    plt.xlabel(col)
    plt.title(col)
    plt.show()

# %%
top = df.groupby("Symbol")["Total Traded Quantity"].sum()

top = top.sort_values(ascending=False)

print(top.head(10))
# Out:
# Symbol
# BAJFINANCE    2354033772
# BAJAUTOFIN      47768191
# Name: Total Traded Quantity, dtype: int64

# %%
top.head(10).plot(kind="bar")
plt.show()

# %%
plt.figure(figsize=(12,5))

plt.plot(df["Date"], df["Close Price"])

plt.title("Close Price Trend")

plt.show()

# %%
print(df.skew(numeric_only=True))
# Out:
# Prev Close               2.075338
# Open Price               2.069722
# High Price               2.073634
# Low Price                2.072516
# Last Price               2.073044
# Close Price              2.073361
# Average Price            2.073002
# Total Traded Quantity    6.693439
# Turnover                 7.506946
# Year                     0.019524
# Month                    0.022488
# dtype: float64

# %%
df["Price Difference"] = df["Close Price"] - df["Open Price"]
df["Price Difference"]
# Out:
# 0        -0.50
# 1         0.00
# 2         1.15
# 3         2.55
# 4         2.00
#          ...
# 4383     96.55
# 4384   -207.55
# 4385    -67.00
# 4386     44.80
# 4387      6.85
# Name: Price Difference, Length: 4388, dtype: float64
